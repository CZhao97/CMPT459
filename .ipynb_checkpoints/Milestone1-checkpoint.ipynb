# %%
from __future__ import print_function
import json
import zipfile
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from scipy import ndimage
import descartes
import geopandas as gpd
import seaborn as sns
sns.set_style('darkgrid')
from shapely.geometry import Point, Polygon

def histplot(data, name=None, kde_flag=True, hist_kws=None):
    plt.figure(figsize = (6,4))
    sns.distplot(data, kde=kde_flag).set(xlabel = name +" histogram")

# %matplotlib inline

# %%
# d, data = None, None
# with zipfile.ZipFile()
rental_train = pd.read_json('train.json')
rental_train.head()
# Out:
#     bathrooms  bedrooms                       building_id  \
# 4         1.0         1  8579a0b0d54db803821a35a4a615e97a
# 6         1.0         2  b8e75fc949a6cd8225b455648a951712
# 9         1.0         2  cd759a988b8f23924b5a2058d5ab2b49
# 10        1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 15        1.0         0  bfb9405149bfff42a92980b594c28234
#
#                 created                                        description  \
# 4   2016-06-16 05:55:27  Spacious 1 Bedroom 1 Bathroom in Williamsburg!...
# 6   2016-06-01 05:44:33  BRAND NEW GUT RENOVATED TRUE 2 BEDROOMFind you...
# 9   2016-06-14 15:19:59  **FLEX 2 BEDROOM WITH FULL PRESSURIZED WALL**L...
# 10  2016-06-24 07:54:24  A Brand New 3 Bedroom 1.5 bath ApartmentEnjoy ...
# 15  2016-06-28 03:50:23  Over-sized Studio w abundant closets. Availabl...
#
#         display_address                                           features  \
# 4   145 Borinquen Place  [Dining Room, Pre-War, Laundry in Building, Di...
# 6             East 44th  [Doorman, Elevator, Laundry in Building, Dishw...
# 9      East 56th Street  [Doorman, Elevator, Laundry in Building, Laund...
# 10  Metropolitan Avenue                                                 []
# 15     East 34th Street  [Doorman, Elevator, Fitness Center, Laundry in...
#
#     latitude  listing_id  longitude                        manager_id  \
# 4    40.7108     7170325   -73.9539  a10db4590843d78c784171a107bdacb4
# 6    40.7513     7092344   -73.9722  955db33477af4f40004820b4aed804a0
# 9    40.7575     7158677   -73.9625  c8b10a317b766204f08e613cef4ce7a0
# 10   40.7145     7211212   -73.9425  5ba989232d0489da1b5f2c45f6688adc
# 15   40.7439     7225292   -73.9743  2c3b41f588fbb5234d8a1e885a436cfa
#
#                                                photos  price  \
# 4   [https://photos.renthop.com/2/7170325_3bb5ac84...   2400
# 6   [https://photos.renthop.com/2/7092344_7663c19a...   3800
# 9   [https://photos.renthop.com/2/7158677_c897a134...   3495
# 10  [https://photos.renthop.com/2/7211212_1ed4542e...   3000
# 15  [https://photos.renthop.com/2/7225292_901f1984...   2795
#
#              street_address interest_level
# 4       145 Borinquen Place         medium
# 6             230 East 44th            low
# 9      405 East 56th Street         medium
# 10  792 Metropolitan Avenue         medium
# 15     340 East 34th Street            low

# %%
# Use temp variable to filter the missing value. Better visulization
# rental_train_latitude = rental_train[rental_train['latitude'] != 0]
# rental_train_longitude = rental_train[rental_train['longitude'] != 0]
# rental_train_latitude = rental_train_latitude['latitude']
# rental_train_longitude = rental_train_longitude['longitude']

# %%
# GeoPandas 101: Plot any data with a latitude and longitude on a map
# https://towardsdatascience.com/geopandas-101-plot-any-data-with-a-latitude-and-longitude-on-a-map-98e01944b972

#nyu_street = gpd.read_file('geo_export_e3a2bd16-bf8f-4453-a5f7-ae7580dc3aaa.shp')

# crs = {'init' : 'epsg:4326'}
# geometry = [Point(xy) for xy in zip( rental_train_longitude , rental_train_latitude )]
# geo_df = gpd.GeoDataFrame(rental_train_latitude, crs = crs, geometry = geometry)

# fig,ax = plt.subplots(figsize = (15,15))
# #nyu_street.plot(ax = ax, alpha = 0.4, color = "grey")
# geo_df[geo_df['price'] <= 3000].plot(ax = ax, markersize = 20, color = 'blue', marker = 'o' , label = '< 3000')
# geo_df[geo_df['price'] > 3000].plot(ax = ax, markersize = 20, color = 'red', marker = '^' , label = '> 3000')
# plt.legend(prop = {'size' : 15})

# %%
# fig, ax = plt.subplots(figsize = (15,15))
# geo_df[geo_df['price'] <= 3000].plot(ax = ax, markersize = 20, color = 'blue', marker = 'o' , label = '< 3000')
# geo_df[geo_df['price'] > 3000].plot(ax = ax, markersize = 20, color = 'red', marker = '^' , label = '> 3000')

# %% [markdown]
# <b>Exploratory data analysis(Use the training dataset (. . . train)to perform EDA)</b>
# 1. Plot histograms for the following numeric columns: Price, Latitude & Longitude.
# 2. Plot hour-wise listing trend and find out the top 5 busiest hours of postings.
# 3. Visualization to show the proportion of target variable values.

# %%
# Cite: https://realpython.com/python-histograms/
# price = rental_train[rental_train['price'] < 15000]
# price = price['price']
# plt.xlabel('price histogram', fontsize=12)
# sns.distplot(price_clean['price'])

print(rental_train.shape)
numOfRow = rental_train.shape[0]
# clean price
price_front_percentile = np.percentile(rental_train.price, 0.5)
price_end_percentile = np.percentile(rental_train.price, 99.5)
price_clean = rental_train[(rental_train['price'] < np.int(price_end_percentile)) & (rental_train['price'] > np.int(price_front_percentile))]

price_clean = price_clean['price']

# clean lat&lon
lat_up = 40.95
lat_down = 40.5
lon_left = -74.1
lon_right = -73.8

lat_clean = rental_train[ (lat_up >= rental_train['latitude']) & (rental_train['latitude'] >= lat_down)]
lon_clean = rental_train[ (lon_right >= rental_train['longitude']) & (rental_train['longitude'] >= lon_left)]
lat_lon_clean = rental_train[ (lat_up >= rental_train['latitude']) & (rental_train['latitude'] >= lat_down) & (lon_right >= rental_train['longitude']) & (rental_train['longitude'] >= lon_left)]
print("number of records cleaned out by lat: ", numOfRow-lat_clean.shape[0])
print("number of records cleaned out by lon: ", numOfRow-lon_clean.shape[0])
print("number of records cleaned out by lat and lon: ", numOfRow-lat_lon_clean.shape[0])


lat_clean = lat_clean['latitude']
lon_clean = lon_clean['longitude']

# 1.
histplot(price_clean, 'price')
# histplot(lat_clean, 'latitude')
# histplot(lon_clean, 'longitude')

histplot(lat_lon_clean['latitude'], 'latitude')
histplot(lat_lon_clean['longitude'], 'longitude')
# Out:
# (49352, 15)
# number of records cleaned out by lat:  44
# number of records cleaned out by lon:  109
# number of records cleaned out by lat and lon:  113

# %%
sns.distplot(np.clip(rental_train["price"], 0, 15000), bins=333, color='b', hist_kws=dict(alpha=0.5))

# %%
# 2.
rental_train['created'] = pd.to_datetime(rental_train['created'])
# rental_train.iloc[0]['created']
rental_train['created_hour'] = rental_train['created'].dt.hour
histplot(rental_train['created'].dt.hour, 'hour', False)

# counts_df = pd.Series(range(24))
counts = np.zeros(24)
for i in range(rental_train.shape[0]):
    counts[rental_train.iloc[i]['created'].hour-1] += 1 
counts = pd.Series(counts)

# %%
counts.index = np.arange(1, len(counts)+1)
print("the top 5 busiest hours of postings:\ntime counts")
print(counts.nlargest(5))
# Out:
# the top 5 busiest hours of postings:
# time counts
# 2    10596.0
# 3     8318.0
# 5     7954.0
# 1     5749.0
# 4     5021.0
# dtype: float64

# %%
# 3.
rental_train_group = rental_train.groupby('interest_level')
rental_train_group.size()
interests = pd.DataFrame(rental_train_group.size())
interests.columns = ['count']
interests.plot.pie(y='count',figsize=(8,10),fontsize=20)
plt.title('PieChart of Interest Level', fontsize=20)

plt.figure(figsize = (6,4))
index = pd.Series.tolist(interests.index)
value = pd.Series.tolist(rental_train_group.size())
y_pos = np.arange(len(index))
plt.bar(y_pos, value)
plt.xticks(y_pos, index,fontsize=15)
plt.ylabel('counts')
plt.title('Barplot of Interest Level', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Barplot of Interest Level')

# %%
# Extract prices of each interest level and visaulize them accordingly

# before excluding price outliers
print(rental_train_group.agg({'price':['min','max','mean']}))

# after cleaning
price_front_percentile = np.percentile(rental_train.price, 0.5)
price_end_percentile = np.percentile(rental_train.price, 99.5)

price_clean = rental_train[(rental_train['price'] < np.int(price_end_percentile)) & (rental_train['price'] > np.int(price_front_percentile))]
print(price_clean.groupby('interest_level').agg({'price':['min','max','mean']}))

high = price_clean[price_clean['interest_level']=='high']
low = price_clean[price_clean['interest_level']=='low']
medium = price_clean[price_clean['interest_level']=='medium']

histplot(high['price'], 'interest price', False)
# histplot(low['price'], 'low interest price')
# histplot(medium['price'], 'medium interest price')
sns.distplot(low['price'], color='g', kde=False, hist_kws=dict(alpha=0.1))
sns.distplot(medium['price'], color='r', kde=False, hist_kws=dict(alpha=0.1)).legend(['high','low','medium'])
# Out:
#                price
#                  min      max         mean
# interest_level
# high             700   111111  2700.293045
# low               43  4490000  4176.599142
# medium           695    15000  3158.767388
#                price
#                  min    max         mean
# interest_level
# high            1395  13200  2732.488998
# low             1395  15046  3804.771755
# medium          1395  15000  3167.790999

# %% [markdown]
# <b> Dealing with missing values,outliers</b>
#  1. Find out the number of missing values in each variable.
#  2. Find out the number of outliers in each variable. Plot visualizations to
#     demonstrate them.You can either remove the outliers or provide a
#     short argument as to why outlier detection is not meaningful for that attribute.
#  3. Can we safely drop the missing values? If not, how will you deal withthem?

# %%
rental_train.head()
# Out:
#     bathrooms  bedrooms                       building_id             created  \
# 4         1.0         1  8579a0b0d54db803821a35a4a615e97a 2016-06-16 05:55:27
# 6         1.0         2  b8e75fc949a6cd8225b455648a951712 2016-06-01 05:44:33
# 9         1.0         2  cd759a988b8f23924b5a2058d5ab2b49 2016-06-14 15:19:59
# 10        1.5         3  53a5b119ba8f7b61d4e010512e0dfc85 2016-06-24 07:54:24
# 15        1.0         0  bfb9405149bfff42a92980b594c28234 2016-06-28 03:50:23
#
#                                           description      display_address  \
# 4   Spacious 1 Bedroom 1 Bathroom in Williamsburg!...  145 Borinquen Place
# 6   BRAND NEW GUT RENOVATED TRUE 2 BEDROOMFind you...            East 44th
# 9   **FLEX 2 BEDROOM WITH FULL PRESSURIZED WALL**L...     East 56th Street
# 10  A Brand New 3 Bedroom 1.5 bath ApartmentEnjoy ...  Metropolitan Avenue
# 15  Over-sized Studio w abundant closets. Availabl...     East 34th Street
#
#                                              features  latitude  listing_id  \
# 4   [Dining Room, Pre-War, Laundry in Building, Di...   40.7108     7170325
# 6   [Doorman, Elevator, Laundry in Building, Dishw...   40.7513     7092344
# 9   [Doorman, Elevator, Laundry in Building, Laund...   40.7575     7158677
# 10                                                 []   40.7145     7211212
# 15  [Doorman, Elevator, Fitness Center, Laundry in...   40.7439     7225292
#
#     longitude                        manager_id  \
# 4    -73.9539  a10db4590843d78c784171a107bdacb4
# 6    -73.9722  955db33477af4f40004820b4aed804a0
# 9    -73.9625  c8b10a317b766204f08e613cef4ce7a0
# 10   -73.9425  5ba989232d0489da1b5f2c45f6688adc
# 15   -73.9743  2c3b41f588fbb5234d8a1e885a436cfa
#
#                                                photos  price  \
# 4   [https://photos.renthop.com/2/7170325_3bb5ac84...   2400
# 6   [https://photos.renthop.com/2/7092344_7663c19a...   3800
# 9   [https://photos.renthop.com/2/7158677_c897a134...   3495
# 10  [https://photos.renthop.com/2/7211212_1ed4542e...   3000
# 15  [https://photos.renthop.com/2/7225292_901f1984...   2795
#
#              street_address interest_level  created_hour
# 4       145 Borinquen Place         medium             5
# 6             230 East 44th            low             5
# 9      405 East 56th Street         medium            15
# 10  792 Metropolitan Avenue         medium             7
# 15     340 East 34th Street            low             3

# %%
# 1.
#0 bath/bedroom value would not be considered missing
bath_bed_missing = rental_train[(rental_train['bathrooms'] == 0.0) | (rental_train['bedrooms'] == 0.0)]
bath_bed_missing

#lat/lontitude outliers & 0 values could be fixed by street address
lat_lon_missing = rental_train[(rental_train['latitude']==0.0) | (rental_train['longitude']==0.0)]
# lat_lon_missing

# Price have no missing data, but the outlier
price_missing = rental_train[rental_train['price'] == 0]
# price_missing

# created_hour have no missing data 
created_hour_missing = rental_train[rental_train['created_hour'] == None]
# created_hour_missing

buildingID_missing = rental_train[rental_train['building_id'] == "0"]
count_buildingID_missing = len(buildingID_missing)
# buildingID_missing

# Count distinct number of manager_id
# ManagerID have no missing data
count_managerID = rental_train.groupby('manager_id').count()
# count_managerID


bath_bed_missing
# Out:
#         bathrooms  bedrooms                       building_id  \
# 15            1.0         0  bfb9405149bfff42a92980b594c28234
# 19            1.0         0  d48767c37a934daaf0bbb0e58c755d0c
# 23            0.0         1  d1ca33a2853e64fad6e4009d5d5d168f
# 33            1.0         0  e74f18ba1001ceae531209fbdc702a58
# 38            1.0         0  2787598123c55dbf45b514958909c79c
# ...           ...       ...                               ...
# 123950        1.0         0                                 0
# 123966        1.0         0                                 0
# 123979        1.0         0  52ae92ff4bc909627f26e8384acd4e37
# 123985        1.0         0                                 0
# 123998        1.0         0                                 0
#
#                    created                                        description  \
# 15     2016-06-28 03:50:23  Over-sized Studio w abundant closets. Availabl...
# 19     2016-06-05 05:28:22  No Fee Large Renovated Sun Splashed Studio. Wa...
# 23     2016-06-09 04:42:03  Extra large one bedroom apartment located in P...
# 33     2016-06-04 02:21:27  Location: Upper East SideAmazing studio with h...
# 38     2016-06-25 05:28:30  This is a luxurious JR 1 bedroom with tons of ...
# ...                    ...                                                ...
# 123950 2016-04-10 04:57:21
# 123966 2016-04-02 13:51:10  This spacious studio features both stainless s...
# 123979 2016-04-21 03:13:45  Fantastic deal on a sunny studio in midtown ea...
# 123985 2016-04-12 02:53:58  Very spacious and sunny studio. Fully equipped...
# 123998 2016-04-02 01:29:32  This studio apartment is located in Hell's Kit...
#
#          display_address                                           features  \
# 15      East 34th Street  [Doorman, Elevator, Fitness Center, Laundry in...
# 19           York Avenue  [Elevator, Laundry in Building, Dishwasher, Ha...
# 23           E 19 Street                                  [Hardwood Floors]
# 33          E 80th St.\r  [Doorman, Elevator, Laundry in Building, Dogs ...
# 38      West 42nd Street  [Swimming Pool, Roof Deck, Doorman, Elevator, ...
# ...                  ...                                                ...
# 123950       40th Street  [Elevator, Cats Allowed, Dogs Allowed, Exclusive]
# 123966       West Street  [Common Outdoor Space, Cats Allowed, Dogs Allo...
# 123979       E 53 Street                                             [Loft]
# 123985  1661 York Avenue  [Elevator, Pre-War, Laundry in Building, Laund...
# 123998  West 49th Street   [Fireplace, Pre-War, Dogs Allowed, Cats Allowed]
#
#         latitude  listing_id  longitude                        manager_id  \
# 15       40.7439     7225292   -73.9743  2c3b41f588fbb5234d8a1e885a436cfa
# 19       40.7769     7114138   -73.9467  9cbfa7a31ae9dfba70b4383636d99788
# 23       40.7346     7131094   -73.9811  b89e62bf8cdc98e9fb8b97d9bc627197
# 33       40.7723     7107333   -73.9510  7e22b26535b913275de0f9ff4f1d6965
# 38       40.7610     7216312   -73.9990  66ad3cc67d71f41d549eef8b40ed26b9
# ...          ...         ...        ...                               ...
# 123950   40.7391     6853029   -73.9255  62826f3ae01f2ddc93b9cd28c659ab2b
# 123966   40.7074     6817040   -74.0105  26d69329a0f3b9abecbddd6abcb5b622
# 123979   40.7559     6905365   -73.9658  bc9a2ff7c931ce7de08f50d429134a16
# 123985   40.7769     6858449   -73.9467  b05bf5018f5763c9befff759e35cc8bd
# 123998   40.7640     6812513   -73.9917  8b53ccf4338806ab1be3dd0267711649
#
#                                                    photos  price  \
# 15      [https://photos.renthop.com/2/7225292_901f1984...   2795
# 19      [https://photos.renthop.com/2/7114138_68d035c3...   1945
# 23      [https://photos.renthop.com/2/7131094_2117d8a9...   2435
# 33      [https://photos.renthop.com/2/7107333_b11b9f27...   2785
# 38      [https://photos.renthop.com/2/7216312_beb173a1...   2400
# ...                                                   ...    ...
# 123950                                                 []   1725
# 123966  [https://photos.renthop.com/2/6817040_dd05fd01...   3000
# 123979  [https://photos.renthop.com/2/6905365_ad971819...   1850
# 123985  [https://photos.renthop.com/2/6858449_df71dc97...   1950
# 123998  [https://photos.renthop.com/2/6812513_ff385b2e...   2175
#
#               street_address interest_level  created_hour
# 15      340 East 34th Street            low             3
# 19          1661 York Avenue           high             5
# 23           346 E 19 Street            low             4
# 33          420 E 80th St.\r            low             2
# 38      620 West 42nd Street         medium             5
# ...                      ...            ...           ...
# 123950     48-30 40th Street            low             4
# 123966           West Street            low            13
# 123979       338 E 53 Street            low             3
# 123985      1661 York Avenue            low             2
# 123998  465 West 49th Street            low             1
#
# [9631 rows x 16 columns]

# %% [markdown]
# <b> Feature extraction from images and text</b>
#  1. Extract features from the images and transform it into data that’s ready to be
#     used in the model for classification.
#  2. Extract features from the text data and transform it into data that’s ready to be
#     used in the model for classification.

# %%
# 1.

# Get number of photos of each rental posting 
def count_num_photos(photo_list):
    return len(photo_list)

rental_train['num_photos'] = rental_train['photos'].apply(count_num_photos)
rental_train.head()
# Out:
#     bathrooms  bedrooms                       building_id             created  \
# 4         1.0         1  8579a0b0d54db803821a35a4a615e97a 2016-06-16 05:55:27
# 6         1.0         2  b8e75fc949a6cd8225b455648a951712 2016-06-01 05:44:33
# 9         1.0         2  cd759a988b8f23924b5a2058d5ab2b49 2016-06-14 15:19:59
# 10        1.5         3  53a5b119ba8f7b61d4e010512e0dfc85 2016-06-24 07:54:24
# 15        1.0         0  bfb9405149bfff42a92980b594c28234 2016-06-28 03:50:23
#
#                                           description      display_address  \
# 4   Spacious 1 Bedroom 1 Bathroom in Williamsburg!...  145 Borinquen Place
# 6   BRAND NEW GUT RENOVATED TRUE 2 BEDROOMFind you...            East 44th
# 9   **FLEX 2 BEDROOM WITH FULL PRESSURIZED WALL**L...     East 56th Street
# 10  A Brand New 3 Bedroom 1.5 bath ApartmentEnjoy ...  Metropolitan Avenue
# 15  Over-sized Studio w abundant closets. Availabl...     East 34th Street
#
#                                              features  latitude  listing_id  \
# 4   [Dining Room, Pre-War, Laundry in Building, Di...   40.7108     7170325
# 6   [Doorman, Elevator, Laundry in Building, Dishw...   40.7513     7092344
# 9   [Doorman, Elevator, Laundry in Building, Laund...   40.7575     7158677
# 10                                                 []   40.7145     7211212
# 15  [Doorman, Elevator, Fitness Center, Laundry in...   40.7439     7225292
#
#     longitude                        manager_id  \
# 4    -73.9539  a10db4590843d78c784171a107bdacb4
# 6    -73.9722  955db33477af4f40004820b4aed804a0
# 9    -73.9625  c8b10a317b766204f08e613cef4ce7a0
# 10   -73.9425  5ba989232d0489da1b5f2c45f6688adc
# 15   -73.9743  2c3b41f588fbb5234d8a1e885a436cfa
#
#                                                photos  price  \
# 4   [https://photos.renthop.com/2/7170325_3bb5ac84...   2400
# 6   [https://photos.renthop.com/2/7092344_7663c19a...   3800
# 9   [https://photos.renthop.com/2/7158677_c897a134...   3495
# 10  [https://photos.renthop.com/2/7211212_1ed4542e...   3000
# 15  [https://photos.renthop.com/2/7225292_901f1984...   2795
#
#              street_address interest_level  created_hour  num_photos
# 4       145 Borinquen Place         medium             5          12
# 6             230 East 44th            low             5           6
# 9      405 East 56th Street         medium            15           6
# 10  792 Metropolitan Avenue         medium             7           5
# 15     340 East 34th Street            low             3           4
